# %%
from mle_exp_plots import create_boxplots

Rep = 20
eta_true = 1.0
mu_true = 0.5
T_list = [100, 1000]
beta_list = [1,]

# Generate boxplots
exp_boxplot_summary = create_boxplots(
    T_list,
    beta_list,
    eta_true,
    mu_true,
    Rep,

    # parameters for optimization and timing
    maxiter=80,
    ftol=1e-5,
    time_every=100,
)
# Out:
# ========== BOXPLOT SUMMARY ==========
# T=100, beta=1 | mean=[1.04845257 0.45003855 1.20547171] | std=[0.24002617 0.12309443 0.42253468]
# T=1000, beta=1 | mean=[1.05721126 0.47441301 1.10616637] | std=[0.10168521 0.05197095 0.17943213]

# %%
from mle_exp_plots import create_mse_plot

# Parameters for the simulation
Rep = 20
T_list = [100, 200, 400, 800, 1600]
beta_list = [1,]

eta_true = 1.0
mu_true = 0.5

# Generate and plot MSE
exp_mse_summary = create_mse_plot(
    T_list,
    beta_list,
    eta_true,
    mu_true,
    Rep,

    # parameters for optimization and timing
    maxiter=80,
    ftol=1e-5,
    time_every=100,
)
# Out:
# ========== Exp MLE | MSE vs T ==========
# beta=1 | mse_eta=[0.05996021 0.03920687 0.02088977 0.00761586 0.00427027] | mse_mu=[0.01764838 0.012452   0.00428698 0.00176416 0.0013129 ] | mse_beta=[0.22075418 0.16878515 0.05891837 0.0148667  0.01346761]

# %%
from mle_power_plots import plot_estimates
import mpmath as mp
mp.mp.dps = 8

T_list = [1000, ]
gamma_list = [2.5,]
eta_true = 1.0
mu_true = 0.5
a = 1.5
burn_in = 100.0
R = 20

power_boxplot_summary = plot_estimates(
    T_list=T_list,
    gamma_list=gamma_list,
    eta_true=eta_true,
    mu_true=mu_true,
    a_true=a,
    R=R,

    # parameters for optimization and timing
    maxiter=80,
    ftol=1e-5,
    time_every=100,
)
# Out:
# Running T=1000, gamma=2.5 ...

# %%
from mle_power_plots import plot_mse_vs_T

R = 20
T_list = [100, 200, 400, 800, 1600]
gamma_list = [2.5, ]
eta_true = 1.0
mu_true = 0.5
a = 1.5

burn_in = 100.0
labels = ["eta", "mu", "gamma"]

power_mse_summary = plot_mse_vs_T(
    T_list,
    gamma_list,
    eta_true,
    mu_true,
    a,
    burn_in,
    R,
    
    # parameters for optimization and timing
    maxiter=80,
    ftol=1e-5,
    time_every=100,
)
# Out:
# Starting T=100, gamma=2.5...
# Starting T=200, gamma=2.5...
# Starting T=400, gamma=2.5...
# Starting T=800, gamma=2.5...
# Starting T=1600, gamma=2.5...

# %%
from data_gener import binsized, ogata_power_hawkes, Branching
from spectral import powerlaw_periodogram_plot, exp_periodogram_plot, periodogram

exp_events = Branching(T=1000,seed=2025)
powerlaw_events = ogata_power_hawkes(T=1000, mu=0.5, eta=1.0, gamma=2.5, a=1.5, burn_in = 0, seed=2025)

# print(periodogram(binsized(exp_events, Delta=0.25, T=1000)))

exp_periodogram_plot(
    events=exp_events, 
    delta=0.25, 
    T=1000, 
    para=[1.0, 0.5, 1.0], 
    alias=3)

powerlaw_periodogram_plot(
    events=powerlaw_events, 
    delta=0.25, 
    T=1000, 
    para=[1.0, 0.5, 2.5], 
    a=1.5, 
    alias=3)

# %%
from whittle_exp_plots import whittle_exp_boxplot

# Define parameters
eta_true = 1.0
mu_true = 0.5
beta_list = [1.0, 0.5]  # rows

Delta_list = [2.0, 1.0, 0.5, 0.25]
T_list = [100, 1000]
K_alias = 4
R = 1000

# true_param is passed as the combined array of [eta, mu, beta]
true_param1 = [eta_true, mu_true, beta_list[0]]  
# true_param2 = [eta_true, mu_true, beta_list[1]]  

# Run the simulation for Boxplot
whittle_exp_boxplot_summary = whittle_exp_boxplot(
    true_param1,
    T_list,
    Delta_list,
    R,
    K_alias,

    maxiter=100,
    ftol=1e-6,
    time_every=100,
    print_summary=True,
)

# run_simulation_boxplot(true_param2, T_list, Delta_list, R, K_alias, labels)
# Out:
# T=100, Delta=2.0: Block(100) Time = 1.7695s
# T=100, Delta=2.0: Block(100) Time = 1.7108s
# T=100, Delta=2.0: Block(100) Time = 1.7555s
# T=100, Delta=2.0: Block(100) Time = 1.7746s
# T=100, Delta=2.0: Block(100) Time = 1.7830s
# T=100, Delta=2.0: Block(100) Time = 1.7916s
# T=100, Delta=2.0: Block(100) Time = 1.7836s
# T=100, Delta=2.0: Block(100) Time = 2.0985s
# T=100, Delta=2.0: Block(100) Time = 1.8499s
# T=100, Delta=2.0: Block(100) Time = 1.7316s
# T=100, Delta=1.0: Block(100) Time = 1.2677s
# T=100, Delta=1.0: Block(100) Time = 1.4004s
# T=100, Delta=1.0: Block(100) Time = 1.1344s
# T=100, Delta=1.0: Block(100) Time = 1.4029s
# T=100, Delta=1.0: Block(100) Time = 1.1704s
# T=100, Delta=1.0: Block(100) Time = 1.3640s
# T=100, Delta=1.0: Block(100) Time = 1.2635s
# T=100, Delta=1.0: Block(100) Time = 1.2559s
# T=100, Delta=1.0: Block(100) Time = 1.2508s
# T=100, Delta=1.0: Block(100) Time = 1.1575s
# T=100, Delta=0.5: Block(100) Time = 1.0093s
# T=100, Delta=0.5: Block(100) Time = 0.8249s
# T=100, Delta=0.5: Block(100) Time = 0.8314s
# T=100, Delta=0.5: Block(100) Time = 0.8235s
# T=100, Delta=0.5: Block(100) Time = 0.8583s
# T=100, Delta=0.5: Block(100) Time = 0.8978s
# T=100, Delta=0.5: Block(100) Time = 0.8245s
# T=100, Delta=0.5: Block(100) Time = 0.9228s
# T=100, Delta=0.5: Block(100) Time = 0.8828s
# T=100, Delta=0.5: Block(100) Time = 0.9183s
# T=100, Delta=0.25: Block(100) Time = 0.9219s
# T=100, Delta=0.25: Block(100) Time = 0.8629s
# T=100, Delta=0.25: Block(100) Time = 0.8523s
# T=100, Delta=0.25: Block(100) Time = 0.9215s
# T=100, Delta=0.25: Block(100) Time = 0.8277s
# T=100, Delta=0.25: Block(100) Time = 0.8848s
# T=100, Delta=0.25: Block(100) Time = 0.8769s
# T=100, Delta=0.25: Block(100) Time = 0.9653s
# T=100, Delta=0.25: Block(100) Time = 0.9443s
# T=100, Delta=0.25: Block(100) Time = 0.8457s
# T=1000, Delta=2.0: Block(100) Time = 1.1958s
# T=1000, Delta=2.0: Block(100) Time = 1.1067s
# T=1000, Delta=2.0: Block(100) Time = 1.1647s
# T=1000, Delta=2.0: Block(100) Time = 1.0364s
# T=1000, Delta=2.0: Block(100) Time = 0.9607s
# T=1000, Delta=2.0: Block(100) Time = 0.9988s
# T=1000, Delta=2.0: Block(100) Time = 1.1988s
# T=1000, Delta=2.0: Block(100) Time = 0.9907s
# T=1000, Delta=2.0: Block(100) Time = 1.0217s
# T=1000, Delta=2.0: Block(100) Time = 1.1134s
# T=1000, Delta=1.0: Block(100) Time = 0.8904s
# T=1000, Delta=1.0: Block(100) Time = 0.8884s
# T=1000, Delta=1.0: Block(100) Time = 0.8407s
# T=1000, Delta=1.0: Block(100) Time = 0.8537s
# T=1000, Delta=1.0: Block(100) Time = 0.8710s
# T=1000, Delta=1.0: Block(100) Time = 0.8965s
# T=1000, Delta=1.0: Block(100) Time = 0.8768s
# T=1000, Delta=1.0: Block(100) Time = 0.8580s
# T=1000, Delta=1.0: Block(100) Time = 0.8733s
# T=1000, Delta=1.0: Block(100) Time = 0.8703s
# T=1000, Delta=0.5: Block(100) Time = 1.1233s
# T=1000, Delta=0.5: Block(100) Time = 1.1323s
# T=1000, Delta=0.5: Block(100) Time = 1.1114s
# T=1000, Delta=0.5: Block(100) Time = 1.1411s
# T=1000, Delta=0.5: Block(100) Time = 1.1193s
# T=1000, Delta=0.5: Block(100) Time = 1.1234s
# T=1000, Delta=0.5: Block(100) Time = 1.1847s
# T=1000, Delta=0.5: Block(100) Time = 1.1094s
# T=1000, Delta=0.5: Block(100) Time = 1.0769s
# T=1000, Delta=0.5: Block(100) Time = 1.1447s
# T=1000, Delta=0.25: Block(100) Time = 1.6568s
# T=1000, Delta=0.25: Block(100) Time = 1.6837s
# T=1000, Delta=0.25: Block(100) Time = 1.6327s
# T=1000, Delta=0.25: Block(100) Time = 1.6293s
# T=1000, Delta=0.25: Block(100) Time = 1.6532s
# T=1000, Delta=0.25: Block(100) Time = 1.6300s
# T=1000, Delta=0.25: Block(100) Time = 1.7139s
# T=1000, Delta=0.25: Block(100) Time = 1.5842s
# T=1000, Delta=0.25: Block(100) Time = 1.6925s
# T=1000, Delta=0.25: Block(100) Time = 1.6111s
# ========== Whittle Exp | Boxplot Summary ==========
# T=100, Delta=2.0 | mean=[1.03393174 0.53720582 3.67135714] | std=[1.15394591 0.28018916 4.08107337]
# T=100, Delta=1.0 | mean=[0.96637013 0.50009255 3.19160991] | std=[0.68290841 0.19115639 4.41637658]
# T=100, Delta=0.5 | mean=[1.08730941 0.44509274 2.34991977] | std=[0.42943771 0.13408204 4.63507648]
# T=100, Delta=0.25 | mean=[1.15005314 0.42323221 1.85577057] | std=[0.3244341  0.12389404 4.05029908]
# T=1000, Delta=2.0 | mean=[1.00885027 0.5090446  1.32116148] | std=[0.44591108 0.09630272 1.01195859]
# T=1000, Delta=1.0 | mean=[1.06412853 0.48405916 1.03602011] | std=[0.17228551 0.04829382 0.30726916]
# T=1000, Delta=0.5 | mean=[1.06705744 0.48329894 0.99437254] | std=[0.12107769 0.04677985 0.20464884]
# T=1000, Delta=0.25 | mean=[1.05739644 0.48543384 0.98127136] | std=[0.10303779 0.04552238 0.17136768]

# %%
from whittle_exp_plots import whittle_exp_mse

# Define parameters
eta_true = 1.0
mu_true = 0.5
T_list = [100, 200, 400, 800]
Delta_list = [2.0, 1.0, 0.5, 0.25]
beta_list = [1.0, 0.5]   # rows
K_alias = 3
R = 1000

# Run the simulation
true_param0= [eta_true, mu_true, beta_list[0]]
# true_param1 = [eta_true, mu_true, beta_list[1]]

whittle_exp_mse_summary = whittle_exp_mse(
    true_param0,
    T_list,
    Delta_list,
    R,
    K_alias,

    # parameters for optimization and timing
    maxiter=100,
    ftol=1e-6,
    time_every=100,
    print_summary=True,
)
# run_simulation_mse(true_param1, T_list, Delta_list, R, K_alias)
# Out:
# T=100, Delta=2.0: Block(100) Time = 1.5330s
# T=100, Delta=2.0: Block(100) Time = 1.4096s
# T=100, Delta=2.0: Block(100) Time = 1.4031s
# T=100, Delta=2.0: Block(100) Time = 1.3587s
# T=100, Delta=2.0: Block(100) Time = 1.4970s
# T=100, Delta=2.0: Block(100) Time = 1.4851s
# T=100, Delta=2.0: Block(100) Time = 1.4362s
# T=100, Delta=2.0: Block(100) Time = 1.5998s
# T=100, Delta=2.0: Block(100) Time = 1.4651s
# T=100, Delta=2.0: Block(100) Time = 1.4158s
# T=200, Delta=2.0: Block(100) Time = 1.2137s
# T=200, Delta=2.0: Block(100) Time = 1.0805s
# T=200, Delta=2.0: Block(100) Time = 1.2080s
# T=200, Delta=2.0: Block(100) Time = 1.1813s
# T=200, Delta=2.0: Block(100) Time = 1.2338s
# T=200, Delta=2.0: Block(100) Time = 1.2840s
# T=200, Delta=2.0: Block(100) Time = 1.5615s
# T=200, Delta=2.0: Block(100) Time = 1.3826s
# T=200, Delta=2.0: Block(100) Time = 1.5246s
# T=200, Delta=2.0: Block(100) Time = 1.2686s
# T=400, Delta=2.0: Block(100) Time = 0.9938s
# T=400, Delta=2.0: Block(100) Time = 0.9988s
# T=400, Delta=2.0: Block(100) Time = 1.0639s
# T=400, Delta=2.0: Block(100) Time = 1.0701s
# T=400, Delta=2.0: Block(100) Time = 1.1413s
# T=400, Delta=2.0: Block(100) Time = 1.0404s
# T=400, Delta=2.0: Block(100) Time = 1.1283s
# T=400, Delta=2.0: Block(100) Time = 1.0170s
# T=400, Delta=2.0: Block(100) Time = 1.1333s
# T=400, Delta=2.0: Block(100) Time = 0.9945s
# T=800, Delta=2.0: Block(100) Time = 0.8802s
# T=800, Delta=2.0: Block(100) Time = 0.9735s
# T=800, Delta=2.0: Block(100) Time = 1.0737s
# T=800, Delta=2.0: Block(100) Time = 0.9655s
# T=800, Delta=2.0: Block(100) Time = 0.9330s
# T=800, Delta=2.0: Block(100) Time = 0.9870s
# T=800, Delta=2.0: Block(100) Time = 0.9044s
# T=800, Delta=2.0: Block(100) Time = 0.8708s
# T=800, Delta=2.0: Block(100) Time = 0.8688s
# T=800, Delta=2.0: Block(100) Time = 0.9653s
# T=100, Delta=1.0: Block(100) Time = 1.0246s
# T=100, Delta=1.0: Block(100) Time = 1.2119s
# T=100, Delta=1.0: Block(100) Time = 0.9080s
# T=100, Delta=1.0: Block(100) Time = 1.0242s
# T=100, Delta=1.0: Block(100) Time = 0.9066s
# T=100, Delta=1.0: Block(100) Time = 1.0932s
# T=100, Delta=1.0: Block(100) Time = 0.9764s
# T=100, Delta=1.0: Block(100) Time = 1.0132s
# T=100, Delta=1.0: Block(100) Time = 1.0143s
# T=100, Delta=1.0: Block(100) Time = 0.9353s
# T=200, Delta=1.0: Block(100) Time = 0.8396s
# T=200, Delta=1.0: Block(100) Time = 0.6934s
# T=200, Delta=1.0: Block(100) Time = 0.7511s
# T=200, Delta=1.0: Block(100) Time = 0.7649s
# T=200, Delta=1.0: Block(100) Time = 0.7642s
# T=200, Delta=1.0: Block(100) Time = 0.7726s
# T=200, Delta=1.0: Block(100) Time = 0.7454s
# T=200, Delta=1.0: Block(100) Time = 0.7684s
# T=200, Delta=1.0: Block(100) Time = 0.8505s
# T=200, Delta=1.0: Block(100) Time = 0.8391s
# T=400, Delta=1.0: Block(100) Time = 0.6800s
# T=400, Delta=1.0: Block(100) Time = 0.6631s
# T=400, Delta=1.0: Block(100) Time = 0.6062s
# T=400, Delta=1.0: Block(100) Time = 0.6614s
# T=400, Delta=1.0: Block(100) Time = 0.6822s
# T=400, Delta=1.0: Block(100) Time = 0.7162s
# T=400, Delta=1.0: Block(100) Time = 0.6914s
# T=400, Delta=1.0: Block(100) Time = 0.7489s
# T=400, Delta=1.0: Block(100) Time = 0.6645s
# T=400, Delta=1.0: Block(100) Time = 0.6989s
# T=800, Delta=1.0: Block(100) Time = 0.6848s
# T=800, Delta=1.0: Block(100) Time = 0.7107s
# T=800, Delta=1.0: Block(100) Time = 0.7207s
# T=800, Delta=1.0: Block(100) Time = 0.6918s
# T=800, Delta=1.0: Block(100) Time = 0.6730s
# T=800, Delta=1.0: Block(100) Time = 0.6865s
# T=800, Delta=1.0: Block(100) Time = 0.6844s
# T=800, Delta=1.0: Block(100) Time = 0.6694s
# T=800, Delta=1.0: Block(100) Time = 0.6532s
# T=800, Delta=1.0: Block(100) Time = 0.6722s
# T=100, Delta=0.5: Block(100) Time = 0.8023s
# T=100, Delta=0.5: Block(100) Time = 0.7122s
# T=100, Delta=0.5: Block(100) Time = 0.7879s
# T=100, Delta=0.5: Block(100) Time = 0.6701s
# T=100, Delta=0.5: Block(100) Time = 0.7184s
# T=100, Delta=0.5: Block(100) Time = 0.7476s
# T=100, Delta=0.5: Block(100) Time = 0.6757s
# T=100, Delta=0.5: Block(100) Time = 0.7736s
# T=100, Delta=0.5: Block(100) Time = 0.7051s
# T=100, Delta=0.5: Block(100) Time = 0.7512s
# T=200, Delta=0.5: Block(100) Time = 0.6215s
# T=200, Delta=0.5: Block(100) Time = 0.6541s
# T=200, Delta=0.5: Block(100) Time = 0.6201s
# T=200, Delta=0.5: Block(100) Time = 0.6602s
# T=200, Delta=0.5: Block(100) Time = 0.6163s
# T=200, Delta=0.5: Block(100) Time = 0.6301s
# T=200, Delta=0.5: Block(100) Time = 0.6574s
# T=200, Delta=0.5: Block(100) Time = 0.6546s
# T=200, Delta=0.5: Block(100) Time = 0.6322s
# T=200, Delta=0.5: Block(100) Time = 0.7301s
# T=400, Delta=0.5: Block(100) Time = 0.6676s
# T=400, Delta=0.5: Block(100) Time = 0.6817s
# T=400, Delta=0.5: Block(100) Time = 0.6559s
# T=400, Delta=0.5: Block(100) Time = 0.6377s
# T=400, Delta=0.5: Block(100) Time = 0.6548s
# T=400, Delta=0.5: Block(100) Time = 0.6967s
# T=400, Delta=0.5: Block(100) Time = 0.6862s
# T=400, Delta=0.5: Block(100) Time = 0.6816s
# T=400, Delta=0.5: Block(100) Time = 0.6756s
# T=400, Delta=0.5: Block(100) Time = 0.7069s
# T=800, Delta=0.5: Block(100) Time = 0.8713s
# T=800, Delta=0.5: Block(100) Time = 0.8361s
# T=800, Delta=0.5: Block(100) Time = 0.8482s
# T=800, Delta=0.5: Block(100) Time = 0.8143s
# T=800, Delta=0.5: Block(100) Time = 0.7946s
# T=800, Delta=0.5: Block(100) Time = 0.8469s
# T=800, Delta=0.5: Block(100) Time = 0.8240s
# T=800, Delta=0.5: Block(100) Time = 0.8711s
# T=800, Delta=0.5: Block(100) Time = 0.8632s
# T=800, Delta=0.5: Block(100) Time = 0.9274s
# T=100, Delta=0.25: Block(100) Time = 0.7886s
# T=100, Delta=0.25: Block(100) Time = 0.7398s
# T=100, Delta=0.25: Block(100) Time = 0.7130s
# T=100, Delta=0.25: Block(100) Time = 0.7873s
# T=100, Delta=0.25: Block(100) Time = 0.7262s
# T=100, Delta=0.25: Block(100) Time = 0.8228s
# T=100, Delta=0.25: Block(100) Time = 0.7623s
# T=100, Delta=0.25: Block(100) Time = 0.8377s
# T=100, Delta=0.25: Block(100) Time = 0.8152s
# T=100, Delta=0.25: Block(100) Time = 0.7118s
# T=200, Delta=0.25: Block(100) Time = 0.7322s
# T=200, Delta=0.25: Block(100) Time = 0.7747s
# T=200, Delta=0.25: Block(100) Time = 0.7519s
# T=200, Delta=0.25: Block(100) Time = 0.7634s
# T=200, Delta=0.25: Block(100) Time = 0.7561s
# T=200, Delta=0.25: Block(100) Time = 0.7744s
# T=200, Delta=0.25: Block(100) Time = 0.7635s
# T=200, Delta=0.25: Block(100) Time = 0.7768s
# T=200, Delta=0.25: Block(100) Time = 0.7604s
# T=200, Delta=0.25: Block(100) Time = 0.7762s
# T=400, Delta=0.25: Block(100) Time = 0.8971s
# T=400, Delta=0.25: Block(100) Time = 0.9114s
# T=400, Delta=0.25: Block(100) Time = 0.9249s
# T=400, Delta=0.25: Block(100) Time = 0.9220s
# T=400, Delta=0.25: Block(100) Time = 0.9194s
# T=400, Delta=0.25: Block(100) Time = 0.9374s
# T=400, Delta=0.25: Block(100) Time = 0.9256s
# T=400, Delta=0.25: Block(100) Time = 0.9133s
# T=400, Delta=0.25: Block(100) Time = 0.9060s
# T=400, Delta=0.25: Block(100) Time = 0.9062s
# T=800, Delta=0.25: Block(100) Time = 1.2502s
# T=800, Delta=0.25: Block(100) Time = 1.2492s
# T=800, Delta=0.25: Block(100) Time = 1.3124s
# T=800, Delta=0.25: Block(100) Time = 1.2682s
# T=800, Delta=0.25: Block(100) Time = 1.2848s
# T=800, Delta=0.25: Block(100) Time = 1.2879s
# T=800, Delta=0.25: Block(100) Time = 1.3311s
# T=800, Delta=0.25: Block(100) Time = 1.2386s
# T=800, Delta=0.25: Block(100) Time = 1.3090s
# T=800, Delta=0.25: Block(100) Time = 1.2626s
# ========== Whittle Exp | MSE vs T ==========
# Delta=2.0, beta=1.0 | mean=[0.68440449 0.04069066 8.86537571] | std=[0.43456088 0.02561512 6.57223318]
# Delta=1.0, beta=1.0 | mean=[0.21196223 0.01603641 8.03589932] | std=[0.17305114 0.0131629  9.21712244]
# Delta=0.5, beta=1.0 | mean=[0.08696446 0.01058016 6.29192384] | std=[6.91866557e-02 7.12118666e-03 9.50557934e+00]
# Delta=0.25, beta=1.0 | mean=[0.0631057  0.0105361  4.87111383] | std=[0.04496254 0.00723238 7.16291541]

# %%
from whittle_power_plots import whittle_powerlaw_boxplot
import numpy as np
import mpmath as mp

mp.mp.dps = 8

R = 200
T_list = [100, 1000]
Delta_list = [2.0, 1.0, 0.5, 0.25]
# Delta_list = [1.0, 0.25]
K_alias = 3
a = 1.5
maxiter = 80

true_param = np.array([1.0, 0.5, 2.5], dtype=float)

summary_lines, records = whittle_powerlaw_boxplot(
    T_list=T_list,
    Delta_list=Delta_list,
    true_param=true_param,
    R=R,
    K_alias=K_alias,
    a_true=a,
    maxiter=100,
    k0=80,
    step_hi=4,
    ftol=1e-5,
    eps=1e-3,
    retry_on_fail=True,
    retry_maxiter=100,
    retry_ftol=1e-6,
    time_every=10,
    return_records=True,
)
# Out:
# T=100, Delta=2.0: Block(10) Time = 5.5701s
# T=100, Delta=2.0: Block(10) Time = 5.2160s
# T=100, Delta=2.0: Block(10) Time = 3.1158s
# T=100, Delta=2.0: Block(10) Time = 2.5971s
# T=100, Delta=2.0: Block(10) Time = 4.6696s
# T=100, Delta=2.0: Block(10) Time = 4.7910s
# T=100, Delta=2.0: Block(10) Time = 3.3743s
# T=100, Delta=2.0: Block(10) Time = 3.0426s
# /Users/mingzhang/Documents/Python Projects/Hawkes/hawkes/whittle_opt.py:120: RuntimeWarning: overflow encountered in exp
#   gamma = np.exp(log_gamma)
# T=100, Delta=2.0: Block(10) Time = 3.1206s
# T=100, Delta=2.0: Block(10) Time = 4.0804s
# T=100, Delta=2.0: Block(10) Time = 4.2098s
# T=100, Delta=2.0: Block(10) Time = 3.2364s
# T=100, Delta=2.0: Block(10) Time = 2.3114s
# T=100, Delta=2.0: Block(10) Time = 3.9306s
# T=100, Delta=2.0: Block(10) Time = 1.7089s
# T=100, Delta=2.0: Block(10) Time = 3.1586s
# T=100, Delta=2.0: Block(10) Time = 2.4758s
# T=100, Delta=2.0: Block(10) Time = 3.5066s
# T=100, Delta=2.0: Block(10) Time = 4.4128s
# T=100, Delta=2.0: Block(10) Time = 3.6927s
# T=100, Delta=1.0: Block(10) Time = 10.0576s
# T=100, Delta=1.0: Block(10) Time = 12.4335s
# T=100, Delta=1.0: Block(10) Time = 7.4981s
# T=100, Delta=1.0: Block(10) Time = 9.6323s
# T=100, Delta=1.0: Block(10) Time = 10.1130s
# T=100, Delta=1.0: Block(10) Time = 9.3587s
# T=100, Delta=1.0: Block(10) Time = 8.9277s
# T=100, Delta=1.0: Block(10) Time = 10.0382s
# T=100, Delta=1.0: Block(10) Time = 12.6301s
# T=100, Delta=1.0: Block(10) Time = 9.4815s
# T=100, Delta=1.0: Block(10) Time = 11.3451s
# T=100, Delta=1.0: Block(10) Time = 11.6658s
# /Users/mingzhang/Documents/Python Projects/Hawkes/hawkes/whittle_opt.py:120: RuntimeWarning: overflow encountered in exp
#   gamma = np.exp(log_gamma)
# T=100, Delta=1.0: Block(10) Time = 8.5872s
# T=100, Delta=1.0: Block(10) Time = 10.6162s
# T=100, Delta=1.0: Block(10) Time = 6.7671s
# T=100, Delta=1.0: Block(10) Time = 8.4235s
# T=100, Delta=1.0: Block(10) Time = 12.5697s
# T=100, Delta=1.0: Block(10) Time = 10.3958s
# T=100, Delta=1.0: Block(10) Time = 10.3729s
# T=100, Delta=1.0: Block(10) Time = 9.1263s
# T=100, Delta=0.5: Block(10) Time = 21.7848s
# T=100, Delta=0.5: Block(10) Time = 19.8874s
# T=100, Delta=0.5: Block(10) Time = 21.2442s
# T=100, Delta=0.5: Block(10) Time = 24.7723s
# T=100, Delta=0.5: Block(10) Time = 14.5278s
# T=100, Delta=0.5: Block(10) Time = 15.2921s
# T=100, Delta=0.5: Block(10) Time = 15.2569s
# T=100, Delta=0.5: Block(10) Time = 25.2170s
# T=100, Delta=0.5: Block(10) Time = 18.8215s
# T=100, Delta=0.5: Block(10) Time = 13.2101s
# T=100, Delta=0.5: Block(10) Time = 19.2564s
# T=100, Delta=0.5: Block(10) Time = 17.6353s
# T=100, Delta=0.5: Block(10) Time = 14.4930s
# T=100, Delta=0.5: Block(10) Time = 19.2412s
# T=100, Delta=0.5: Block(10) Time = 20.6880s
# T=100, Delta=0.5: Block(10) Time = 17.7970s
# T=100, Delta=0.5: Block(10) Time = 22.8520s
# T=100, Delta=0.5: Block(10) Time = 14.2766s
# T=100, Delta=0.5: Block(10) Time = 18.3255s
# T=100, Delta=0.5: Block(10) Time = 18.1042s
# T=100, Delta=0.25: Block(10) Time = 14.5289s
# T=100, Delta=0.25: Block(10) Time = 13.3558s
# T=100, Delta=0.25: Block(10) Time = 11.7406s
# T=100, Delta=0.25: Block(10) Time = 19.2264s
# T=100, Delta=0.25: Block(10) Time = 17.2265s
# T=100, Delta=0.25: Block(10) Time = 15.1220s
# T=100, Delta=0.25: Block(10) Time = 18.5580s
# T=100, Delta=0.25: Block(10) Time = 16.8439s
# T=100, Delta=0.25: Block(10) Time = 16.3695s
# T=100, Delta=0.25: Block(10) Time = 18.7397s
# T=100, Delta=0.25: Block(10) Time = 15.4392s
# T=100, Delta=0.25: Block(10) Time = 18.9887s
# T=100, Delta=0.25: Block(10) Time = 18.3750s
# T=100, Delta=0.25: Block(10) Time = 18.0008s
# T=100, Delta=0.25: Block(10) Time = 14.1508s
# T=100, Delta=0.25: Block(10) Time = 19.5661s
# T=100, Delta=0.25: Block(10) Time = 15.7346s
# T=100, Delta=0.25: Block(10) Time = 21.4502s
# T=100, Delta=0.25: Block(10) Time = 14.7789s
# T=100, Delta=0.25: Block(10) Time = 20.7961s
# T=1000, Delta=2.0: Block(10) Time = 16.5471s
# T=1000, Delta=2.0: Block(10) Time = 18.7116s
# T=1000, Delta=2.0: Block(10) Time = 24.5815s
# T=1000, Delta=2.0: Block(10) Time = 17.4997s
# T=1000, Delta=2.0: Block(10) Time = 24.5748s
# T=1000, Delta=2.0: Block(10) Time = 17.8002s
# T=1000, Delta=2.0: Block(10) Time = 19.9575s
# T=1000, Delta=2.0: Block(10) Time = 22.4884s
# T=1000, Delta=2.0: Block(10) Time = 26.3934s
# T=1000, Delta=2.0: Block(10) Time = 17.6326s
# T=1000, Delta=2.0: Block(10) Time = 19.5664s
# T=1000, Delta=2.0: Block(10) Time = 16.2276s
# T=1000, Delta=2.0: Block(10) Time = 22.1316s
# T=1000, Delta=2.0: Block(10) Time = 21.6182s
# T=1000, Delta=2.0: Block(10) Time = 18.2426s
# T=1000, Delta=2.0: Block(10) Time = 17.6612s
# T=1000, Delta=2.0: Block(10) Time = 16.5158s
# T=1000, Delta=2.0: Block(10) Time = 15.7777s
# T=1000, Delta=2.0: Block(10) Time = 17.9487s
# T=1000, Delta=2.0: Block(10) Time = 18.3298s
# T=1000, Delta=1.0: Block(10) Time = 30.8709s
# T=1000, Delta=1.0: Block(10) Time = 28.6725s
# T=1000, Delta=1.0: Block(10) Time = 27.9535s
# T=1000, Delta=1.0: Block(10) Time = 29.8595s
# T=1000, Delta=1.0: Block(10) Time = 35.7914s
# T=1000, Delta=1.0: Block(10) Time = 26.7945s
# T=1000, Delta=1.0: Block(10) Time = 35.0731s
# T=1000, Delta=1.0: Block(10) Time = 31.2936s
# T=1000, Delta=1.0: Block(10) Time = 31.5066s
# T=1000, Delta=1.0: Block(10) Time = 29.1121s
# T=1000, Delta=1.0: Block(10) Time = 31.8985s
# T=1000, Delta=1.0: Block(10) Time = 40.4144s
# T=1000, Delta=1.0: Block(10) Time = 30.3190s
# T=1000, Delta=1.0: Block(10) Time = 30.3091s
# T=1000, Delta=1.0: Block(10) Time = 26.7462s
# T=1000, Delta=1.0: Block(10) Time = 38.0234s
# T=1000, Delta=1.0: Block(10) Time = 34.5214s
# T=1000, Delta=1.0: Block(10) Time = 28.4739s
# T=1000, Delta=1.0: Block(10) Time = 32.1866s
# T=1000, Delta=1.0: Block(10) Time = 36.0662s
# T=1000, Delta=0.5: Block(10) Time = 43.6014s
# T=1000, Delta=0.5: Block(10) Time = 56.3048s
# T=1000, Delta=0.5: Block(10) Time = 46.0464s
# T=1000, Delta=0.5: Block(10) Time = 60.0925s
# T=1000, Delta=0.5: Block(10) Time = 51.5763s
# T=1000, Delta=0.5: Block(10) Time = 53.1435s
# T=1000, Delta=0.5: Block(10) Time = 59.6963s
# T=1000, Delta=0.5: Block(10) Time = 46.7830s
# T=1000, Delta=0.5: Block(10) Time = 54.3169s
# T=1000, Delta=0.5: Block(10) Time = 51.0153s
# T=1000, Delta=0.5: Block(10) Time = 55.9771s
# T=1000, Delta=0.5: Block(10) Time = 63.2614s
# T=1000, Delta=0.5: Block(10) Time = 61.8325s
# T=1000, Delta=0.5: Block(10) Time = 49.8257s
# T=1000, Delta=0.5: Block(10) Time = 54.4848s
# T=1000, Delta=0.5: Block(10) Time = 66.6154s
# T=1000, Delta=0.5: Block(10) Time = 70.4417s
# T=1000, Delta=0.5: Block(10) Time = 55.4818s
# T=1000, Delta=0.5: Block(10) Time = 52.3303s
# T=1000, Delta=0.5: Block(10) Time = 61.1624s
# T=1000, Delta=0.25: Block(10) Time = 66.3172s
# T=1000, Delta=0.25: Block(10) Time = 65.0514s
# T=1000, Delta=0.25: Block(10) Time = 59.2014s
# T=1000, Delta=0.25: Block(10) Time = 50.2923s
# T=1000, Delta=0.25: Block(10) Time = 70.6837s
# T=1000, Delta=0.25: Block(10) Time = 79.9092s
# T=1000, Delta=0.25: Block(10) Time = 68.1022s
# T=1000, Delta=0.25: Block(10) Time = 63.2584s
# T=1000, Delta=0.25: Block(10) Time = 72.7407s
# T=1000, Delta=0.25: Block(10) Time = 69.1296s
# T=1000, Delta=0.25: Block(10) Time = 56.8518s
# T=1000, Delta=0.25: Block(10) Time = 71.8043s
# T=1000, Delta=0.25: Block(10) Time = 51.7148s
# T=1000, Delta=0.25: Block(10) Time = 81.5214s
# T=1000, Delta=0.25: Block(10) Time = 84.1321s
# T=1000, Delta=0.25: Block(10) Time = 71.8639s
# T=1000, Delta=0.25: Block(10) Time = 45.3303s
# T=1000, Delta=0.25: Block(10) Time = 69.8800s
# T=1000, Delta=0.25: Block(10) Time = 71.9262s
# T=1000, Delta=0.25: Block(10) Time = 80.5167s
# ========== SUMMARY ==========
# T=100, Δ=2.0 | mean=[0.52819825 0.61790935 3.92539384] | std=[0.35324086 0.15247235 1.33729869] | Rep=181 | fail=19
# T=100, Δ=1.0 | mean=[0.85877208 0.54862306 3.13634151] | std=[0.54281628 0.14980554 1.65449855] | Rep=191 | fail=9
# T=100, Δ=0.5 | mean=[0.92000722 0.53423919 2.69351642] | std=[0.41462087 0.14101814 1.4995433 ] | Rep=194 | fail=6
# T=100, Δ=0.25 | mean=[0.96468305 0.52082611 2.59567318] | std=[0.37489513 0.14579377 1.31171249] | Rep=198 | fail=2
# T=1000, Δ=2.0 | mean=[0.71923313 0.56821103 3.62467742] | std=[0.37048192 0.07898564 1.36895618] | Rep=195 | fail=5
# T=1000, Δ=1.0 | mean=[0.9678656  0.51558974 2.77687851] | std=[0.30080872 0.05761542 1.1559192 ] | Rep=194 | fail=6
# T=1000, Δ=0.5 | mean=[1.05191924 0.50133643 2.38184055] | std=[0.18389524 0.05614211 0.86361659] | Rep=199 | fail=1
# T=1000, Δ=0.25 | mean=[1.04169115 0.50050233 2.2895529 ] | std=[0.11135624 0.05003728 0.6358173 ] | Rep=200 | fail=0

# %%
from whittle_power_plots import whittle_powerlaw_mse

R = 200
T_list = [100, 200, 400, 800]
# Delta_list = [2.0, 1.0, 0.5, 0.25]
Delta_list = [1.0, 0.25]
gamma_true_list = [2.5,]

K_alias = 4
eta_true = 1.0
mu_true = 0.5

a = 1.5

mse_summary = whittle_powerlaw_mse(
    T_list,
    Delta_list,
    gamma_true_list,
    R,
    K_alias,
    eta_true,
    mu_true,
    a,
    maxiter=100,
    k0=80,
    step_hi=4,
    ftol=1e-6,
    eps=1e-3,
    retry_on_fail=True,
    retry_maxiter=100,
    retry_ftol=1e-6,
    time_every=10,
    print_summary=True,
)
# Out:
# T=100, Delta=1.0: Block(10) Time = 21.0669s
# T=100, Delta=1.0: Block(10) Time = 20.2063s
# T=100, Delta=1.0: Block(10) Time = 8.1783s
# T=100, Delta=1.0: Block(10) Time = 18.2218s
# T=100, Delta=1.0: Block(10) Time = 25.9836s
# T=100, Delta=1.0: Block(10) Time = 21.9390s
# T=100, Delta=1.0: Block(10) Time = 23.0359s
# T=100, Delta=1.0: Block(10) Time = 21.5631s
# T=100, Delta=1.0: Block(10) Time = 16.8598s
# T=100, Delta=1.0: Block(10) Time = 19.9960s
# T=100, Delta=1.0: Block(10) Time = 24.9764s
# T=100, Delta=1.0: Block(10) Time = 22.2608s
# T=100, Delta=1.0: Block(10) Time = 16.3666s
# T=100, Delta=1.0: Block(10) Time = 17.3617s
# T=100, Delta=1.0: Block(10) Time = 12.9596s
# T=100, Delta=1.0: Block(10) Time = 16.0333s
# T=100, Delta=1.0: Block(10) Time = 15.7987s
# T=100, Delta=1.0: Block(10) Time = 15.1684s
# T=100, Delta=1.0: Block(10) Time = 21.2358s
# T=100, Delta=1.0: Block(10) Time = 17.9024s
# T=200, Delta=1.0: Block(10) Time = 32.6253s
# T=200, Delta=1.0: Block(10) Time = 22.6734s
# T=200, Delta=1.0: Block(10) Time = 17.3186s
# T=200, Delta=1.0: Block(10) Time = 26.4000s
# T=200, Delta=1.0: Block(10) Time = 33.0513s
# T=200, Delta=1.0: Block(10) Time = 33.3514s
# T=200, Delta=1.0: Block(10) Time = 25.7083s
# T=200, Delta=1.0: Block(10) Time = 29.4076s
# T=200, Delta=1.0: Block(10) Time = 27.8547s
# T=200, Delta=1.0: Block(10) Time = 22.8871s
# T=200, Delta=1.0: Block(10) Time = 26.3923s
# T=200, Delta=1.0: Block(10) Time = 31.6338s
# T=200, Delta=1.0: Block(10) Time = 25.3637s
# T=200, Delta=1.0: Block(10) Time = 30.5501s
# T=200, Delta=1.0: Block(10) Time = 19.8271s
# T=200, Delta=1.0: Block(10) Time = 37.9244s
# T=200, Delta=1.0: Block(10) Time = 34.6298s
# T=200, Delta=1.0: Block(10) Time = 26.0786s
# T=200, Delta=1.0: Block(10) Time = 31.9880s
# T=200, Delta=1.0: Block(10) Time = 35.9246s
# T=400, Delta=1.0: Block(10) Time = 48.2466s
# T=400, Delta=1.0: Block(10) Time = 34.4115s
# T=400, Delta=1.0: Block(10) Time = 38.3043s
# T=400, Delta=1.0: Block(10) Time = 37.2990s
# T=400, Delta=1.0: Block(10) Time = 31.0921s
# T=400, Delta=1.0: Block(10) Time = 40.6460s
# T=400, Delta=1.0: Block(10) Time = 42.6004s
# T=400, Delta=1.0: Block(10) Time = 41.9409s
# T=400, Delta=1.0: Block(10) Time = 38.5819s
# T=400, Delta=1.0: Block(10) Time = 34.2767s
# T=400, Delta=1.0: Block(10) Time = 34.1775s
# T=400, Delta=1.0: Block(10) Time = 41.4627s
# T=400, Delta=1.0: Block(10) Time = 41.5092s
# T=400, Delta=1.0: Block(10) Time = 38.4588s
# T=400, Delta=1.0: Block(10) Time = 34.7182s
# T=400, Delta=1.0: Block(10) Time = 29.2219s
# T=400, Delta=1.0: Block(10) Time = 41.0219s
# T=400, Delta=1.0: Block(10) Time = 44.6431s
# T=400, Delta=1.0: Block(10) Time = 41.3601s
# T=400, Delta=1.0: Block(10) Time = 43.9491s
# T=800, Delta=1.0: Block(10) Time = 55.4897s
# T=800, Delta=1.0: Block(10) Time = 66.2481s
# T=800, Delta=1.0: Block(10) Time = 53.1881s
# T=800, Delta=1.0: Block(10) Time = 46.0136s
# T=800, Delta=1.0: Block(10) Time = 40.0338s
# T=800, Delta=1.0: Block(10) Time = 51.7567s
# T=800, Delta=1.0: Block(10) Time = 54.7472s
# T=800, Delta=1.0: Block(10) Time = 63.1764s
# T=800, Delta=1.0: Block(10) Time = 37.3295s
# T=800, Delta=1.0: Block(10) Time = 55.2295s
# T=800, Delta=1.0: Block(10) Time = 54.6824s
# T=800, Delta=1.0: Block(10) Time = 51.9253s
# T=800, Delta=1.0: Block(10) Time = 63.7598s
# T=800, Delta=1.0: Block(10) Time = 58.3430s
# T=800, Delta=1.0: Block(10) Time = 58.4239s
# T=800, Delta=1.0: Block(10) Time = 60.4211s
# T=800, Delta=1.0: Block(10) Time = 55.3763s
# T=800, Delta=1.0: Block(10) Time = 52.6333s
# T=800, Delta=1.0: Block(10) Time = 56.9943s
# T=800, Delta=1.0: Block(10) Time = 43.5127s
# T=100, Delta=0.25: Block(10) Time = 27.5392s
# T=100, Delta=0.25: Block(10) Time = 36.4641s
# T=100, Delta=0.25: Block(10) Time = 30.4720s
# T=100, Delta=0.25: Block(10) Time = 36.8096s
# T=100, Delta=0.25: Block(10) Time = 35.7932s
# T=100, Delta=0.25: Block(10) Time = 44.7198s
# T=100, Delta=0.25: Block(10) Time = 29.3936s
# T=100, Delta=0.25: Block(10) Time = 34.8859s
# T=100, Delta=0.25: Block(10) Time = 33.7703s
# T=100, Delta=0.25: Block(10) Time = 47.4085s
# T=100, Delta=0.25: Block(10) Time = 30.9458s
# T=100, Delta=0.25: Block(10) Time = 30.6215s
# T=100, Delta=0.25: Block(10) Time = 29.1735s
# T=100, Delta=0.25: Block(10) Time = 27.1666s
# T=100, Delta=0.25: Block(10) Time = 30.9937s
# T=100, Delta=0.25: Block(10) Time = 24.9770s
# T=100, Delta=0.25: Block(10) Time = 34.0549s
# T=100, Delta=0.25: Block(10) Time = 35.1846s
# T=100, Delta=0.25: Block(10) Time = 27.5543s
# T=100, Delta=0.25: Block(10) Time = 36.2336s
# T=200, Delta=0.25: Block(10) Time = 45.2096s
# T=200, Delta=0.25: Block(10) Time = 44.2846s
# T=200, Delta=0.25: Block(10) Time = 37.2698s
# T=200, Delta=0.25: Block(10) Time = 43.8874s
# T=200, Delta=0.25: Block(10) Time = 39.0116s
# T=200, Delta=0.25: Block(10) Time = 52.8372s
# T=200, Delta=0.25: Block(10) Time = 37.6041s
# T=200, Delta=0.25: Block(10) Time = 42.5384s
# T=200, Delta=0.25: Block(10) Time = 31.9485s
# T=200, Delta=0.25: Block(10) Time = 42.5278s
# T=200, Delta=0.25: Block(10) Time = 39.1712s
# T=200, Delta=0.25: Block(10) Time = 29.3021s
# T=200, Delta=0.25: Block(10) Time = 43.7224s
# T=200, Delta=0.25: Block(10) Time = 53.9713s
# T=200, Delta=0.25: Block(10) Time = 54.0049s
# T=200, Delta=0.25: Block(10) Time = 41.2321s
# T=200, Delta=0.25: Block(10) Time = 51.9487s
# T=200, Delta=0.25: Block(10) Time = 34.6440s
# T=200, Delta=0.25: Block(10) Time = 34.8579s
# T=200, Delta=0.25: Block(10) Time = 34.7983s
# T=400, Delta=0.25: Block(10) Time = 83.2027s
# T=400, Delta=0.25: Block(10) Time = 74.8378s
# T=400, Delta=0.25: Block(10) Time = 70.9729s
# T=400, Delta=0.25: Block(10) Time = 93.6509s
# T=400, Delta=0.25: Block(10) Time = 68.7301s
# T=400, Delta=0.25: Block(10) Time = 64.0980s
# T=400, Delta=0.25: Block(10) Time = 79.0407s
# T=400, Delta=0.25: Block(10) Time = 60.4259s
# T=400, Delta=0.25: Block(10) Time = 84.9750s
# T=400, Delta=0.25: Block(10) Time = 66.1996s
# T=400, Delta=0.25: Block(10) Time = 79.9004s
# T=400, Delta=0.25: Block(10) Time = 82.9571s
# T=400, Delta=0.25: Block(10) Time = 88.4353s
# T=400, Delta=0.25: Block(10) Time = 81.6003s
# T=400, Delta=0.25: Block(10) Time = 79.5753s
# T=400, Delta=0.25: Block(10) Time = 89.2413s
# T=400, Delta=0.25: Block(10) Time = 86.3169s
# T=400, Delta=0.25: Block(10) Time = 74.4340s
# T=400, Delta=0.25: Block(10) Time = 77.3449s
# T=400, Delta=0.25: Block(10) Time = 68.3513s
# T=800, Delta=0.25: Block(10) Time = 90.8386s
# T=800, Delta=0.25: Block(10) Time = 129.7186s
# T=800, Delta=0.25: Block(10) Time = 103.8947s
# T=800, Delta=0.25: Block(10) Time = 139.2060s
# T=800, Delta=0.25: Block(10) Time = 122.8699s
# T=800, Delta=0.25: Block(10) Time = 139.3726s
# T=800, Delta=0.25: Block(10) Time = 102.2588s
# T=800, Delta=0.25: Block(10) Time = 121.5867s
# T=800, Delta=0.25: Block(10) Time = 116.3766s
# T=800, Delta=0.25: Block(10) Time = 111.0813s
# T=800, Delta=0.25: Block(10) Time = 119.9806s
# T=800, Delta=0.25: Block(10) Time = 104.8532s
# T=800, Delta=0.25: Block(10) Time = 107.5061s
# T=800, Delta=0.25: Block(10) Time = 79.9965s
# T=800, Delta=0.25: Block(10) Time = 114.9229s
