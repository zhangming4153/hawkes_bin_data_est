# %%
from mle_exp_plots import create_boxplots

Rep = 20
eta_true = 1.0
mu_true = 0.5
T_list = [100, 1000]
beta_list = [1,]

# Generate boxplots
exp_boxplot_summary = create_boxplots(
    T_list,
    beta_list,
    eta_true,
    mu_true,
    Rep,

    # parameters for optimization and timing
    maxiter=80,
    ftol=1e-5,
    time_every=100,
)
# Out:
# ========== BOXPLOT SUMMARY ==========
# T=100, beta=1 | mean=[1.04845257 0.45003855 1.20547171] | std=[0.24002617 0.12309443 0.42253468]
# T=1000, beta=1 | mean=[1.05721126 0.47441301 1.10616637] | std=[0.10168521 0.05197095 0.17943213]

# %%
from mle_exp_plots import create_mse_plot

# Parameters for the simulation
Rep = 20
T_list = [100, 200, 400, 800, 1600]
beta_list = [1,]

eta_true = 1.0
mu_true = 0.5

# Generate and plot MSE
exp_mse_summary = create_mse_plot(
    T_list,
    beta_list,
    eta_true,
    mu_true,
    Rep,

    # parameters for optimization and timing
    maxiter=80,
    ftol=1e-5,
    time_every=100,
)
# Out:
# ========== Exp MLE | MSE vs T ==========
# beta=1 | mse_eta=[0.05996021 0.03920687 0.02088977 0.00761586 0.00427027] | mse_mu=[0.01764838 0.012452   0.00428698 0.00176416 0.0013129 ] | mse_beta=[0.22075418 0.16878515 0.05891837 0.0148667  0.01346761]

# %%
from mle_power_plots import plot_estimates
import mpmath as mp
mp.mp.dps = 8

T_list = [1000, ]
gamma_list = [2.5,]
eta_true = 1.0
mu_true = 0.5
a = 1.5
burn_in = 100.0
R = 20

power_boxplot_summary = plot_estimates(
    T_list=T_list,
    gamma_list=gamma_list,
    eta_true=eta_true,
    mu_true=mu_true,
    a_true=a,
    R=R,

    # parameters for optimization and timing
    maxiter=80,
    ftol=1e-5,
    time_every=100,
)
# Out:
# Running T=1000, gamma=2.5 ...

# %%
from mle_power_plots import plot_mse_vs_T

R = 20
T_list = [100, 200, 400, 800, 1600]
gamma_list = [2.5, ]
eta_true = 1.0
mu_true = 0.5
a = 1.5

burn_in = 100.0
labels = ["eta", "mu", "gamma"]

power_mse_summary = plot_mse_vs_T(
    T_list,
    gamma_list,
    eta_true,
    mu_true,
    a,
    burn_in,
    R,
    
    # parameters for optimization and timing
    maxiter=80,
    ftol=1e-5,
    time_every=100,
)
# Out:
# Starting T=100, gamma=2.5...
# Starting T=200, gamma=2.5...
# Starting T=400, gamma=2.5...
# Starting T=800, gamma=2.5...
# Starting T=1600, gamma=2.5...

# %%
from data_gener import binsized, ogata_power_hawkes, Branching
from spectral import powerlaw_periodogram_plot, exp_periodogram_plot, periodogram

exp_events = Branching(T=1000,seed=2025)
powerlaw_events = ogata_power_hawkes(T=1000, mu=0.5, eta=1.0, gamma=2.5, a=1.5, burn_in = 0, seed=2025)

# print(periodogram(binsized(exp_events, Delta=0.25, T=1000)))

exp_periodogram_plot(
    events=exp_events, 
    delta=0.25, 
    T=1000, 
    para=[1.0, 0.5, 1.0], 
    alias=3)

powerlaw_periodogram_plot(
    events=powerlaw_events, 
    delta=0.25, 
    T=1000, 
    para=[1.0, 0.5, 2.5], 
    a=1.5, 
    alias=3)

# %%
from whittle_exp_plots import run_simulation_boxplot

# Define parameters
eta_true = 1.0
mu_true = 0.5
beta_list = [1.0, 0.5]  # rows

Delta_list = [2.0, 1.0, 0.5, 0.25]
T_list = [100, 1000]
K_alias = 4
R = 1000
labels = ["eta", "mu", "beta"]

# true_param is passed as the combined array of [eta, mu, beta]
true_param1 = [eta_true, mu_true, beta_list[0]]  
# true_param2 = [eta_true, mu_true, beta_list[1]]  

# Run the simulation for Boxplot
whittle_exp_boxplot_summary = run_simulation_boxplot(
    true_param1,
    T_list,
    Delta_list,
    R,
    K_alias,
    maxiter=80,
    ftol=1e-5,
    time_every=100,
    print_summary=True,
)

# run_simulation_boxplot(true_param2, T_list, Delta_list, R, K_alias, labels)
# Out:
# T=100, Delta=2.0: Block(100) Time = 1.0043s
# T=100, Delta=2.0: Block(100) Time = 1.0122s
# T=100, Delta=2.0: Block(100) Time = 1.0157s
# T=100, Delta=2.0: Block(100) Time = 1.0301s
# T=100, Delta=2.0: Block(100) Time = 1.0869s
# T=100, Delta=2.0: Block(100) Time = 1.1160s
# T=100, Delta=2.0: Block(100) Time = 1.0884s
# T=100, Delta=2.0: Block(100) Time = 1.1055s
# T=100, Delta=2.0: Block(100) Time = 1.0718s
# T=100, Delta=2.0: Block(100) Time = 1.1132s
# T=100, Delta=1.0: Block(100) Time = 0.8547s
# T=100, Delta=1.0: Block(100) Time = 0.9000s
# T=100, Delta=1.0: Block(100) Time = 0.8427s
# T=100, Delta=1.0: Block(100) Time = 0.8774s
# T=100, Delta=1.0: Block(100) Time = 0.7921s
# T=100, Delta=1.0: Block(100) Time = 0.9447s
# T=100, Delta=1.0: Block(100) Time = 0.8781s
# T=100, Delta=1.0: Block(100) Time = 0.8321s
# T=100, Delta=1.0: Block(100) Time = 0.8826s
# T=100, Delta=1.0: Block(100) Time = 0.8373s
# T=100, Delta=0.5: Block(100) Time = 0.7454s
# T=100, Delta=0.5: Block(100) Time = 0.6775s
# T=100, Delta=0.5: Block(100) Time = 0.7090s
# T=100, Delta=0.5: Block(100) Time = 0.6846s
# T=100, Delta=0.5: Block(100) Time = 0.7198s
# T=100, Delta=0.5: Block(100) Time = 0.7872s
# T=100, Delta=0.5: Block(100) Time = 0.6937s
# T=100, Delta=0.5: Block(100) Time = 0.7343s
# T=100, Delta=0.5: Block(100) Time = 0.7118s
# T=100, Delta=0.5: Block(100) Time = 0.7293s
# T=100, Delta=0.25: Block(100) Time = 0.8131s
# T=100, Delta=0.25: Block(100) Time = 0.7960s
# T=100, Delta=0.25: Block(100) Time = 0.7929s
# T=100, Delta=0.25: Block(100) Time = 0.8020s
# T=100, Delta=0.25: Block(100) Time = 0.7471s
# T=100, Delta=0.25: Block(100) Time = 0.8274s
# T=100, Delta=0.25: Block(100) Time = 0.8029s
# T=100, Delta=0.25: Block(100) Time = 0.8584s
# T=100, Delta=0.25: Block(100) Time = 0.8912s
# T=100, Delta=0.25: Block(100) Time = 0.8007s
# T=1000, Delta=2.0: Block(100) Time = 0.6829s
# T=1000, Delta=2.0: Block(100) Time = 0.6270s
# T=1000, Delta=2.0: Block(100) Time = 0.6103s
# T=1000, Delta=2.0: Block(100) Time = 0.5605s
# T=1000, Delta=2.0: Block(100) Time = 0.5377s
# T=1000, Delta=2.0: Block(100) Time = 0.5759s
# T=1000, Delta=2.0: Block(100) Time = 0.6320s
# T=1000, Delta=2.0: Block(100) Time = 0.6497s
# T=1000, Delta=2.0: Block(100) Time = 0.5990s
# T=1000, Delta=2.0: Block(100) Time = 0.6177s
# T=1000, Delta=1.0: Block(100) Time = 0.6455s
# T=1000, Delta=1.0: Block(100) Time = 0.6830s
# T=1000, Delta=1.0: Block(100) Time = 0.6208s
# T=1000, Delta=1.0: Block(100) Time = 0.6556s
# T=1000, Delta=1.0: Block(100) Time = 0.6692s
# T=1000, Delta=1.0: Block(100) Time = 0.6750s
# T=1000, Delta=1.0: Block(100) Time = 0.6862s
# T=1000, Delta=1.0: Block(100) Time = 0.6581s
# T=1000, Delta=1.0: Block(100) Time = 0.6816s
# T=1000, Delta=1.0: Block(100) Time = 0.6782s
# T=1000, Delta=0.5: Block(100) Time = 0.8854s
# T=1000, Delta=0.5: Block(100) Time = 1.0027s
# T=1000, Delta=0.5: Block(100) Time = 0.8756s
# T=1000, Delta=0.5: Block(100) Time = 0.9100s
# T=1000, Delta=0.5: Block(100) Time = 0.9138s
# T=1000, Delta=0.5: Block(100) Time = 0.9015s
# T=1000, Delta=0.5: Block(100) Time = 0.9480s
# T=1000, Delta=0.5: Block(100) Time = 0.8597s
# T=1000, Delta=0.5: Block(100) Time = 0.9020s
# T=1000, Delta=0.5: Block(100) Time = 0.8983s
# T=1000, Delta=0.25: Block(100) Time = 1.4052s
# T=1000, Delta=0.25: Block(100) Time = 1.3666s
# T=1000, Delta=0.25: Block(100) Time = 1.3412s
# T=1000, Delta=0.25: Block(100) Time = 1.3825s
# T=1000, Delta=0.25: Block(100) Time = 1.4142s
# T=1000, Delta=0.25: Block(100) Time = 1.3241s
# T=1000, Delta=0.25: Block(100) Time = 1.3779s
# T=1000, Delta=0.25: Block(100) Time = 1.3893s
# T=1000, Delta=0.25: Block(100) Time = 1.3380s
# T=1000, Delta=0.25: Block(100) Time = 1.3395s
# ========== Whittle Exp | Boxplot Summary ==========
# T=100, Delta=2.0 | mean=[1.15859989 0.48024826 2.36801073] | std=[1.0727368  0.25231824 1.72122567]
# T=100, Delta=1.0 | mean=[1.02864736 0.47499164 2.27473052] | std=[0.67759501 0.17736895 2.46947593]
# T=100, Delta=0.5 | mean=[1.106236   0.43783526 1.86668242] | std=[0.41894462 0.12869538 2.55750819]
# T=100, Delta=0.25 | mean=[1.15200614 0.42222026 1.76462669] | std=[0.3222715  0.12334422 3.17507844]
# T=1000, Delta=2.0 | mean=[1.06023245 0.48862301 1.11289128] | std=[0.30752592 0.07176779 0.4653838 ]
# T=1000, Delta=1.0 | mean=[1.06776404 0.48285046 1.0325677 ] | std=[0.16755275 0.04853611 0.27960156]
# T=1000, Delta=0.5 | mean=[1.06858632 0.48274081 0.99450661] | std=[0.12153313 0.04663468 0.19480978]
# T=1000, Delta=0.25 | mean=[1.05806244 0.4852293  0.98074722] | std=[0.10304788 0.04525194 0.16446966]

# %%
from whittle_exp_plots import run_simulation_mse

# Define parameters
eta_true = 1.0
mu_true = 0.5
T_list = [100, 200, 400, 800]
Delta_list = [2.0, 1.0, 0.5, 0.25]
beta_list = [1.0, 0.5]   # rows
K_alias = 3
R = 200

# Run the simulation
true_param0= [eta_true, mu_true, beta_list[0]]
# true_param1 = [eta_true, mu_true, beta_list[1]]

whittle_exp_mse_summary = run_simulation_mse(
    true_param0,
    T_list,
    Delta_list,
    R,
    K_alias,

    # parameters for optimization and timing
    maxiter=80,
    ftol=1e-5,
    time_every=100,
    print_summary=True,
)
# run_simulation_mse(true_param1, T_list, Delta_list, R, K_alias)
# Out:
# T=100, Delta=2.0: Block(100) Time = 0.9781s
# T=100, Delta=2.0: Block(100) Time = 0.8908s
# T=200, Delta=2.0: Block(100) Time = 0.7777s
# T=200, Delta=2.0: Block(100) Time = 0.6797s
# T=400, Delta=2.0: Block(100) Time = 0.5687s
# T=400, Delta=2.0: Block(100) Time = 0.5611s
# T=800, Delta=2.0: Block(100) Time = 0.5510s
# T=800, Delta=2.0: Block(100) Time = 0.5671s
# T=100, Delta=1.0: Block(100) Time = 0.6907s
# T=100, Delta=1.0: Block(100) Time = 0.7387s
# T=200, Delta=1.0: Block(100) Time = 0.6316s
# T=200, Delta=1.0: Block(100) Time = 0.5782s
# T=400, Delta=1.0: Block(100) Time = 0.5657s
# T=400, Delta=1.0: Block(100) Time = 0.5436s
# T=800, Delta=1.0: Block(100) Time = 0.5219s
# T=800, Delta=1.0: Block(100) Time = 0.5456s
# T=100, Delta=0.5: Block(100) Time = 0.5951s
# T=100, Delta=0.5: Block(100) Time = 0.5442s
# T=200, Delta=0.5: Block(100) Time = 0.5549s
# T=200, Delta=0.5: Block(100) Time = 0.5859s
# T=400, Delta=0.5: Block(100) Time = 0.5806s
# T=400, Delta=0.5: Block(100) Time = 0.5962s
# T=800, Delta=0.5: Block(100) Time = 0.6861s
# T=800, Delta=0.5: Block(100) Time = 0.7102s
# T=100, Delta=0.25: Block(100) Time = 0.6623s
# T=100, Delta=0.25: Block(100) Time = 0.6619s
# T=200, Delta=0.25: Block(100) Time = 0.6691s
# T=200, Delta=0.25: Block(100) Time = 0.6868s
# T=400, Delta=0.25: Block(100) Time = 0.8058s
# T=400, Delta=0.25: Block(100) Time = 0.8160s
# T=800, Delta=0.25: Block(100) Time = 1.0638s
# T=800, Delta=0.25: Block(100) Time = 1.1233s
# ========== Whittle Exp | MSE vs T ==========
# Delta=2.0, beta=1.0 | mean=[0.57243762 0.03250967 2.52165329] | std=[0.48108885 0.02584927 2.08639084]
# Delta=1.0, beta=1.0 | mean=[0.19144706 0.01362357 2.77303277] | std=[0.14890079 0.01027996 3.19897703]
# Delta=0.5, beta=1.0 | mean=[0.09822928 0.01178285 1.74874447] | std=[0.08625151 0.0084864  2.63249297]
# Delta=0.25, beta=1.0 | mean=[0.06329904 0.01106647 2.53638292] | std=[0.04369359 0.00767263 4.14999888]

# %%
from whittle_power_plots import run_powerlaw_boxplot_grid
import numpy as np
import mpmath as mp

mp.mp.dps = 8

R = 200
T_list = [100, 1000]
Delta_list = [2.0, 1.0, 0.5, 0.25]
# Delta_list = [1.0, 0.25]
K_alias = 3
a = 1.5
maxiter = 80

true_param = np.array([1.0, 0.5, 2.5], dtype=float)

summary_lines, records = run_powerlaw_boxplot_grid(
    T_list=T_list,
    Delta_list=Delta_list,
    true_param=true_param,
    R=R,
    K_alias=K_alias,
    a_true=a,
    maxiter=80,
    k0=80,
    step_hi=5,
    ftol=1e-5,
    eps=1e-3,
    retry_on_fail=True,
    retry_maxiter=80,
    retry_ftol=1e-6,
    time_every=10,
    return_records=True,
)
# Out:
# T=100, Delta=2.0: Block(10) Time = 5.5701s
# T=100, Delta=2.0: Block(10) Time = 5.2160s
# T=100, Delta=2.0: Block(10) Time = 3.1158s
# T=100, Delta=2.0: Block(10) Time = 2.5971s
# T=100, Delta=2.0: Block(10) Time = 4.6696s
# T=100, Delta=2.0: Block(10) Time = 4.7910s
# T=100, Delta=2.0: Block(10) Time = 3.3743s
# T=100, Delta=2.0: Block(10) Time = 3.0426s
# /Users/mingzhang/Documents/Python Projects/Hawkes/hawkes/whittle_opt.py:120: RuntimeWarning: overflow encountered in exp
#   gamma = np.exp(log_gamma)
# T=100, Delta=2.0: Block(10) Time = 3.1206s
# T=100, Delta=2.0: Block(10) Time = 4.0804s
# T=100, Delta=2.0: Block(10) Time = 4.2098s
# T=100, Delta=2.0: Block(10) Time = 3.2364s
# T=100, Delta=2.0: Block(10) Time = 2.3114s
# T=100, Delta=2.0: Block(10) Time = 3.9306s
# T=100, Delta=2.0: Block(10) Time = 1.7089s
# T=100, Delta=2.0: Block(10) Time = 3.1586s
# T=100, Delta=2.0: Block(10) Time = 2.4758s
# T=100, Delta=2.0: Block(10) Time = 3.5066s
# T=100, Delta=2.0: Block(10) Time = 4.4128s
# T=100, Delta=2.0: Block(10) Time = 3.6927s
# T=100, Delta=1.0: Block(10) Time = 10.0576s
# T=100, Delta=1.0: Block(10) Time = 12.4335s
# T=100, Delta=1.0: Block(10) Time = 7.4981s
# T=100, Delta=1.0: Block(10) Time = 9.6323s
# T=100, Delta=1.0: Block(10) Time = 10.1130s
# T=100, Delta=1.0: Block(10) Time = 9.3587s
# T=100, Delta=1.0: Block(10) Time = 8.9277s
# T=100, Delta=1.0: Block(10) Time = 10.0382s
# T=100, Delta=1.0: Block(10) Time = 12.6301s
# T=100, Delta=1.0: Block(10) Time = 9.4815s
# T=100, Delta=1.0: Block(10) Time = 11.3451s
# T=100, Delta=1.0: Block(10) Time = 11.6658s
# /Users/mingzhang/Documents/Python Projects/Hawkes/hawkes/whittle_opt.py:120: RuntimeWarning: overflow encountered in exp
#   gamma = np.exp(log_gamma)
# T=100, Delta=1.0: Block(10) Time = 8.5872s
# T=100, Delta=1.0: Block(10) Time = 10.6162s
# T=100, Delta=1.0: Block(10) Time = 6.7671s
# T=100, Delta=1.0: Block(10) Time = 8.4235s
# T=100, Delta=1.0: Block(10) Time = 12.5697s
# T=100, Delta=1.0: Block(10) Time = 10.3958s
# T=100, Delta=1.0: Block(10) Time = 10.3729s
# T=100, Delta=1.0: Block(10) Time = 9.1263s
# T=100, Delta=0.5: Block(10) Time = 21.7848s
# T=100, Delta=0.5: Block(10) Time = 19.8874s
# T=100, Delta=0.5: Block(10) Time = 21.2442s
# T=100, Delta=0.5: Block(10) Time = 24.7723s
# T=100, Delta=0.5: Block(10) Time = 14.5278s
# T=100, Delta=0.5: Block(10) Time = 15.2921s
# T=100, Delta=0.5: Block(10) Time = 15.2569s
# T=100, Delta=0.5: Block(10) Time = 25.2170s
# T=100, Delta=0.5: Block(10) Time = 18.8215s
# T=100, Delta=0.5: Block(10) Time = 13.2101s
# T=100, Delta=0.5: Block(10) Time = 19.2564s
# T=100, Delta=0.5: Block(10) Time = 17.6353s
# T=100, Delta=0.5: Block(10) Time = 14.4930s

# %%
import mpmath as mp
from whittle_power_plots import run_powerlaw_mse_grid

mp.mp.dps = 8

R = 50
T_list = [100, 200, 400, 800]
# Delta_list = [2.0, 1.0, 0.5, 0.25]
Delta_list = [1.0, 0.25]
gamma_true_list = [2.5,]

K_alias = 3
eta_true = 1.0
mu_true = 0.5

a = 1.5
maxiter = 80

mse_summary = run_powerlaw_mse_grid(
    T_list,
    Delta_list,
    gamma_true_list,
    R,
    K_alias,
    eta_true,
    mu_true,
    a,
    maxiter=80,
    k0=80,
    step_hi=5,
    ftol=1e-5,
    eps=1e-3,
    retry_on_fail=True,
    retry_maxiter=80,
    retry_ftol=1e-6,
    time_every=10,
    print_summary=True,
)
# Out:
# T=100, Delta=1.0: Block(10) Time = 12.3074s
# T=100, Delta=1.0: Block(10) Time = 9.8340s
# T=100, Delta=1.0: Block(10) Time = 7.5082s
# T=100, Delta=1.0: Block(10) Time = 8.5763s
# T=100, Delta=1.0: Block(10) Time = 13.3952s
# T=200, Delta=1.0: Block(10) Time = 20.5121s
# T=200, Delta=1.0: Block(10) Time = 11.7872s
# T=200, Delta=1.0: Block(10) Time = 11.1974s
# T=200, Delta=1.0: Block(10) Time = 16.3569s
# T=200, Delta=1.0: Block(10) Time = 22.9528s
# T=400, Delta=1.0: Block(10) Time = 29.9437s
# T=400, Delta=1.0: Block(10) Time = 16.8005s
# T=400, Delta=1.0: Block(10) Time = 25.2912s
# T=400, Delta=1.0: Block(10) Time = 26.2008s
# T=400, Delta=1.0: Block(10) Time = 21.0411s
# T=800, Delta=1.0: Block(10) Time = 25.8028s
# T=800, Delta=1.0: Block(10) Time = 33.7614s
# T=800, Delta=1.0: Block(10) Time = 28.8455s
# T=800, Delta=1.0: Block(10) Time = 33.0355s
# T=800, Delta=1.0: Block(10) Time = 28.5071s
# T=100, Delta=0.25: Block(10) Time = 14.2802s
# T=100, Delta=0.25: Block(10) Time = 17.1492s
# T=100, Delta=0.25: Block(10) Time = 16.1580s
# T=100, Delta=0.25: Block(10) Time = 21.3698s
# T=100, Delta=0.25: Block(10) Time = 18.4495s
# T=200, Delta=0.25: Block(10) Time = 30.9019s
# T=200, Delta=0.25: Block(10) Time = 26.6648s
# T=200, Delta=0.25: Block(10) Time = 26.0945s
# T=200, Delta=0.25: Block(10) Time = 21.1639s
# T=200, Delta=0.25: Block(10) Time = 24.8305s
# T=400, Delta=0.25: Block(10) Time = 44.0766s
# T=400, Delta=0.25: Block(10) Time = 32.3191s
# T=400, Delta=0.25: Block(10) Time = 43.4900s
# T=400, Delta=0.25: Block(10) Time = 45.3467s
# T=400, Delta=0.25: Block(10) Time = 37.5891s
# T=800, Delta=0.25: Block(10) Time = 60.1597s
# T=800, Delta=0.25: Block(10) Time = 71.0059s
# T=800, Delta=0.25: Block(10) Time = 58.3427s
# T=800, Delta=0.25: Block(10) Time = 82.3743s
# T=800, Delta=0.25: Block(10) Time = 71.9313s
# ========== Whittle Power | MSE vs T ==========
# Gamma=2.5, Delta=1.0 | mean=[0.21962346 0.01938775 2.28802742] | std=[0.07242576 0.01573258 0.48385983]
# Gamma=2.5, Delta=0.25 | mean=[0.07261437 0.00958643 1.1899336 ] | std=[0.0504578  0.00700402 0.4065732 ]
